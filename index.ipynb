# %% [markdown]
# # NoSQL Databases - Quiz
#
#
# ## Introduction
#
# In this lesson, we'll try our luck with some common open-ended interview questions about NoSQL databases.
#
#
# ## Question 1
#
# What is the difference between a NoSQL and a SQL database?  Which is better?
#
# Write your answer below this line:
# _____SQL DB is a relational DB and structured Data. It is vertically scalable and can be expanding by the hardware.SQL use structured query languages to define data. There is no hierarchical for store SQLDB. WE use SQLDB for complexity queries.
#            NoSql is a non relational DB and unstructured DB. It is horizontally scalable and can be lessen the work by assigning workload to multiple servers that work simultaneously.We can add new data to NoSql without prior permission. There is no standard interface in NoSql, so it is difficult to query complex queries________________________________________________________________________________________________________Sql and NoSql are used for different purposes, depending on data sources, data type, kind of queries ( simple or complex). They are all good for theirs purposes__________________
#
#
#
#
#
#
#
# ## Question 2
#
# Describe a situation where a NoSQL database might be a better choice than a relational database, and explain your reasoning.
#
# Write your answer below this line:
# ____If I worked as general manager for a computer company that has its stores across nation and oversea, at the end of everyday, I would like to know how many computers were sold with their accessories. By let each store reports it sales, and then combining the results after, it will get info very fast and without complication. _________________________________________________________________________________________________________________________
#
#
#
#
#
#
# ## Question 3
#
# How does MongoDB work? How is it different from a relational database?
#
# Write your answer below this line:
# _______________________________________________________________________________________________________________________________
#
#
#
#
#
#
#
#
# ## Question 4
#
# What is fault tolerance, and what does it have to do with Resilient Distributed Datasets?
#
# Write your answer below this line:
# _______________________________________________________________________________________________________________________________
#
#
#
#
#
#
#
#
# ## Question 5
#
# What is MapReduce? How is it related to Hadoop?
#
# Write your answer below this line:
# _______________________________________________________________________________________________________________________________
#
#
#
#
# ## Summary
#
#
# In this lesson, we reviewed some common NoSQL interview questions.
